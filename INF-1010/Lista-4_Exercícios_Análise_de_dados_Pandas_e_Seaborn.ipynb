# %% [markdown]
# # **Titanic Dataset**
#
# Este é um conjunto de dados clássico usado em muitos tutoriais e demos de mineração de dados - perfeito para iniciar a análise exploratória e construir modelos de classificação binários para prever a sobrevivência.
#
# Os dados abrangem apenas os passageiros, não a tripulação.
#
# ###As características dos dados são
# * survived - Sobrevivente (0 = Não; 1 = Sim)
# * pclass - Classe do passageiro
# * sex - Sexo
# * age - Idade
# * sibsp - Número de irmãos/cônjuges a bordo
# * parch - Número de pais/filhos a bordo
# * fare - Tarifa do passageiro
# * embark_town - Porto de embarque
# * class - Classe do passageiro
# * who - informa se era homem, mulher ou criança
# * alone - informa se o passageiro estava sozinho

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Crie um DataFrame utilizando o dataset importado e mostre as 5 primeiras linhas do DataFrame.**

# %%
dataset = sns.load_dataset('titanic')
dataset
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
titanic_df = pd.DataFrame(data=dataset)
titanic_df
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# ##### Resultado esperado
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Verifique se há registros incompletos e caso encontre, faça a remoção desses registros**

# %%
titanic_df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# checking which columns have missing values
titanic_df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# double checking which columns have missing values
titanic_df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# deleting rows with missing values 

titanic_clean_df = titanic_df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
titanic_clean_df
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 6           0       1    male  54.0  ...     E  Southampton     no   True
# 10          1       3  female   4.0  ...     G  Southampton    yes  False
# 11          1       1  female  58.0  ...     C  Southampton    yes   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 871         1       1  female  47.0  ...     D  Southampton    yes  False
# 872         0       1    male  33.0  ...     B  Southampton     no   True
# 879         1       1  female  56.0  ...     C    Cherbourg    yes  False
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
#
# [182 rows x 15 columns]

# %%
# making sure there are no missing values
titanic_clean_df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# ### **Verifique os tipos dos atributos e apresente a descrição dos atributos numéricos.**

# %%
# checking the number of rows and columns 
titanic_clean_df.shape
# Out:
# (182, 15)

# %%
# getting the name of the columns 
titanic_clean_df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# understanding the type of data existing in each column
titanic_clean_df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# obtaining basic statistics from the numerical columns 
titanic_clean_df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  182.000000  182.000000  182.000000  182.000000  182.000000  182.000000
# mean     0.675824    1.192308   35.623187    0.467033    0.478022   78.919735
# std      0.469357    0.516411   15.671615    0.645007    0.755869   76.490774
# min      0.000000    1.000000    0.920000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   24.000000    0.000000    0.000000   29.700000
# 50%      1.000000    1.000000   36.000000    0.000000    0.000000   57.000000
# 75%      1.000000    1.000000   47.750000    1.000000    1.000000   90.000000
# max      1.000000    3.000000   80.000000    3.000000    4.000000  512.329200

# %%
# Describing all columns of a DataFrame regardless of data type
titanic_clean_df.describe(include='all')
# Out:
#           survived      pclass   sex         age  ...  deck  embark_town  alive  alone
# count   182.000000  182.000000   182  182.000000  ...   182          182    182    182
# unique         NaN         NaN     2         NaN  ...     7            3      2      2
# top            NaN         NaN  male         NaN  ...     C  Southampton    yes  False
# freq           NaN         NaN    94         NaN  ...    51          115    123    104
# mean      0.675824    1.192308   NaN   35.623187  ...   NaN          NaN    NaN    NaN
# std       0.469357    0.516411   NaN   15.671615  ...   NaN          NaN    NaN    NaN
# min       0.000000    1.000000   NaN    0.920000  ...   NaN          NaN    NaN    NaN
# 25%       0.000000    1.000000   NaN   24.000000  ...   NaN          NaN    NaN    NaN
# 50%       1.000000    1.000000   NaN   36.000000  ...   NaN          NaN    NaN    NaN
# 75%       1.000000    1.000000   NaN   47.750000  ...   NaN          NaN    NaN    NaN
# ...

# %% [markdown]
# ##### Resultado esperado
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Calcule o total de sobreviventes, idade média dos passageiros, e o número de homens e mulheres a bordo**

# %%
# Number of survived passengers
total_survived = titanic_clean_df.query("survived == 1").survived.count()
total_survived
# Out:
# 123

# %%
# Number of survived passengers
(titanic_clean_df.survived == 1).sum()
# Out:
# 123

# %%
# Average age of the passengers
age_average = titanic_clean_df.age.mean()
age_average
# Out:
# 35.62318681318681

# %%
# Average age of the passengers
age_average_1 = titanic_clean_df.age.mean()
round(age_average_1, 3)
# Out:
# 35.623

# %%
# Number of men 
total_men = titanic_clean_df.query("sex == 'male'").sex.count()
total_men
# Out:
# 94

# %%
# Number of men 
total_men_1 = titanic_clean_df[titanic_clean_df['sex'] == 'male'].sex.count()
total_men_1
# Out:
# 94

# %%
# Number of men
total_men_2 = (titanic_clean_df.sex.values == 'male').sum()
total_men_2
# Out:
# 94

# %%
# Number of women
total_women = titanic_clean_df.sex.count() - total_men
total_women
# Out:
# 88

# %%
# Number of women
total_women_1 = titanic_clean_df.query("sex == 'female'").sex.count()
total_women_1
# Out:
# 88

# %%
# Number of women
total_women_2 = titanic_clean_df[titanic_clean_df['sex'] == 'female'].sex.count()
total_women_2
# Out:
# 88

# %% [markdown]
# ##### Resultado esperado
#
# <pre>
# Total sobreviventes: 123
# Idade média dos passageiros: 35.62318681318681
# Total de homens: 94
# Total de mulheres: 88
# </pre>

# %% [markdown]
# ### **Gere uma visualização para a quantidade de homens e mulheres a bordo**

# %%
# with the cleaned data - histplot
sns.histplot(data=titanic_clean_df, x="sex", hue="survived", multiple="dodge", shrink=.8);

# %%
# with the whole data - histplot
sns.histplot(data=titanic_df, x="sex", hue="survived", multiple="dodge", shrink=.8);

# %%
# with the cleaned data - countplot
ax = sns.countplot(x="sex", hue="survived", data=titanic_clean_df)
ax;

# %%
# with the whole data - countplot
plt.figure(figsize=(7,6))
ax = sns.countplot(x="sex", hue="survived", data=titanic_df)
ax;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Gere uma visualização que resuma o intevalo das idades dos passageiros considerando seu sexo e se o passageiro sobreviveu.**

# %%
# with cleaned data - seaborn
ax = sns.violinplot(x="sex", y="age", hue="survived", data=titanic_clean_df)
ax;

# %%
# with cleaned data - seaborn
ax = sns.violinplot(x="sex", y="age", hue="survived", data=titanic_clean_df, palette="muted", split=True)
ax;

# %%
# with the whole data - seaborn
ax = sns.violinplot(x="sex", y="age", hue="survived", data=titanic_df)
ax;

# %%
# with the whole data - seaborn
ax = sns.violinplot(x="sex", y="age", hue="survived", data=titanic_df, palette="muted", split=True)
ax;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Gere uma visualização do tipo boxplot que mostre a tarifa de acordo com a classe dos passageiros**

# %%
# with the cleaned data
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="pclass", y="fare", data=titanic_clean_df)
ax;

# %%
# with the whole data
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="pclass", y="fare", data=titanic_df)
ax;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Gere uma visualização que mostre a correlação dos atributos no dataset**

# %%
corr = titanic_clean_df.corr()
corr
# Out:
#             survived    pclass       age  ...      fare  adult_male     alone
# survived    1.000000 -0.037698 -0.251045  ...  0.130632   -0.582727 -0.111827
# pclass     -0.037698  1.000000 -0.305708  ... -0.316796   -0.122403  0.064678
# age        -0.251045 -0.305708  1.000000  ... -0.090730    0.338384  0.203460
# sibsp       0.101376 -0.105262 -0.154160  ...  0.284841   -0.147610 -0.628796
# parch       0.018739  0.046273 -0.269757  ...  0.388540   -0.183689 -0.549197
# fare        0.130632 -0.316796 -0.090730  ...  1.000000   -0.114147 -0.298233
# adult_male -0.582727 -0.122403  0.338384  ... -0.114147    1.000000  0.193695
# alone      -0.111827  0.064678  0.203460  ... -0.298233    0.193695  1.000000
#
# [8 rows x 8 columns]

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr);

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr, cmap="YlGnBu");

# %%
palette = sns.diverging_palette(20, 220, n=256)

plt.figure(figsize=(10,8))
sns.heatmap(corr, cmap= palette);

# %%
palette = sns.diverging_palette(220, 20, n=7)

plt.figure(figsize=(10,8))
sns.heatmap(corr, cmap= palette);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Gere uma visualização que mostre os sobreviventes de acordo com seu sexo e sua classe**

# %%
# with the whole data
sns.relplot(
    data=titanic_df, x="survived", y="age",
    col="pclass", hue="sex", style="sex",
    kind="scatter"
);

# %%
sns.catplot(
    data=titanic_df, x="survived", y="age",
    col="pclass", hue="sex",
    kind="swarm"
);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#criando o dataframe
covidCampinas_df = pd.read_csv("covid_CAMPINAS.csv", sep=",")
covidCampinas_df.head(5)
# Out:
#                                  document_id  ... vacina_numdose
# 0  ab97ebb2-d5a4-49bf-82e0-820cd766ee70-i0b0  ...              1
# 1  a9cd0331-67a3-421b-b8c7-2743a975e9f6-i0b0  ...              1
# 2  cab120c7-ef28-4c5a-a006-89aeb40d4d31-i0b0  ...              1
# 3  97a8a762-7ef4-48bb-a09e-bafa077dba0e-i0b0  ...              1
# 4  5f701442-cc80-47d2-ba84-12f307c71b61-i0b0  ...              1
#
# [5 rows x 35 columns]

# %%
covidCampinas_df.shape
# Out:
# (27625, 35)

# %%
#fazendo o drop da coluna document_id
covidCampinas_df.drop(columns=['document_id', "data_importacao_rnds"], inplace=True)
covidCampinas_df.head(3)
# Out:
#                                          paciente_id  ...  vacina_numdose
# 0  2e51f02d12646146d052b6319f70baa6c09ba401c9a5e2...  ...               1
# 1  e59477534caa148b0c43cbc22f372857e0a9dcb7a8d321...  ...               1
# 2  a7f6affdca43ee817f42469ddef2e123b640a0c67a8c97...  ...               1
#
# [3 rows x 33 columns]

# %%
#removendo linhas duplicadas, se existirem
covidCampinas_df = covidCampinas_df.drop_duplicates()
covidCampinas_df.shape

#haviam 57 linhas duplicadas
# Out:
# (27566, 33)

# %%
#garantindo que temos apenas dados de estabelecimentos de saúde de Campinas
covidCampinas_df['estabelecimento_municipio_nome'].unique()
# Out:
# array(['CAMPINAS'], dtype=object)

# %%
#equivalência entre descrição da dose e o seu código
print(covidCampinas_df['vacina_descricao_dose'].unique())
print(covidCampinas_df['vacina_numdose'].unique())
# Out:
# ['1ª Dose' '2ª Dose' 'Reforço' 'Dose']
# [ 1  2 38  8]

# %%
#entendendo as métricas das colunas com valores contínuos
covidCampinas_df.describe()
# Out:
#        paciente_idade  ...  vacina_numdose
# count    27565.000000  ...    27566.000000
# mean        45.510902  ...        3.602046
# std         18.332129  ...        7.916667
# min         12.000000  ...        1.000000
# 25%         31.000000  ...        1.000000
# 50%         43.000000  ...        2.000000
# 75%         59.000000  ...        2.000000
# max        121.000000  ...       38.000000
#
# [8 rows x 13 columns]

# %%
#colunas com dados nulos
covidCampinas_df.isna().sum()
# Out:
# paciente_id                                     1
# paciente_idade                                  1
# paciente_datanascimento                         1
# paciente_enumsexobiologico                      1
# paciente_racacor_codigo                         1
# paciente_racacor_valor                          1
# paciente_endereco_coibgemunicipio              77
# paciente_endereco_copais                       77
# paciente_endereco_nmmunicipio                  77
# paciente_endereco_nmpais                       77
# paciente_endereco_uf                           77
# paciente_endereco_cep                        1032
# paciente_nacionalidade_enumnacionalidade        5
# estabelecimento_valor                           0
# estabelecimento_razaosocial                     0
# estalecimento_nofantasia                        0
# estabelecimento_municipio_codigo                0
# estabelecimento_municipio_nome                  0
# estabelecimento_uf                              0
# vacina_grupoatendimento_codigo                  0
# vacina_grupoatendimento_nome                    0
# vacina_categoria_codigo                         0
# vacina_categoria_nome                           0
# vacina_lote                                     0
# vacina_fabricante_nome                          0
# vacina_fabricante_referencia                27566
# vacina_dataaplicacao                            0
# vacina_descricao_dose                           0
# vacina_codigo                                   0
# vacina_nome                                     0
# sistema_origem                                  0
# id_sistema_origem                               0
# vacina_numdose                                  0
# dtype: int64

# %%
#removendo coluna "vacina_fabricante_referencia"
covidCampinas_df.drop(columns=["vacina_fabricante_referencia"], inplace=True)
covidCampinas_df.head(3)
# Out:
#                                          paciente_id  ...  vacina_numdose
# 0  2e51f02d12646146d052b6319f70baa6c09ba401c9a5e2...  ...               1
# 1  e59477534caa148b0c43cbc22f372857e0a9dcb7a8d321...  ...               1
# 2  a7f6affdca43ee817f42469ddef2e123b640a0c67a8c97...  ...               1
#
# [3 rows x 32 columns]

# %%
#agrupando pelas doses
groupDoses = covidCampinas_df.groupby(['vacina_descricao_dose', 'paciente_enumsexobiologico']).size().reset_index(name='count_rows')
groupDoses
# Out:
#   vacina_descricao_dose paciente_enumsexobiologico  count_rows
# 0               1ª Dose                          F        5852
# 1               1ª Dose                          M        4915
# 2               2ª Dose                          F        7849
# 3               2ª Dose                          M        6544
# 4                  Dose                          F         482
# 5                  Dose                          M         573
# 6               Reforço                          F         873
# 7               Reforço                          M         477

# %%
groupDoses.pivot("vacina_descricao_dose", "paciente_enumsexobiologico", "count_rows").plot(kind='bar')

plt.show()

# %%
#valores únicos dos endereços dos pacientes vacinados
covidCampinas_df['paciente_endereco_nmmunicipio'].unique()
# Out:
# array(['CAMPINAS', 'REGINOPOLIS', 'AMERICANA', 'ITABORAI', 'FORMOSA',
#        'TERESINA', 'SAO JOSE DO RIO PRETO', 'SACRAMENTO', 'ANDRADAS',
#        'HORTOLANDIA', 'ITAIPULANDIA', 'MANAUS', 'ATIBAIA', 'RIO CLARO',
#        'SAO PAULO', 'MESSIAS', 'GUARULHOS', 'SUMARE', 'FORTALEZA', nan,
#        'ITU', 'JUNDIAI', 'MOJI MIRIM', 'IGARACU DO TIETE', 'PROMISSAO',
#        'MOCOCA', 'JAMBEIRO', 'FLORIANOPOLIS', 'VINHEDO', 'RECIFE',
#        'COSMOPOLIS', 'BELO HORIZONTE', 'RIO QUENTE', 'JAU', 'JAGUARIUNA',
#        'ANTONIO GONCALVES', 'MONTE MOR', 'OLIMPIA', 'VALINHOS',
#        'VARGINHA', 'BAURU', 'CAMPOS GERAIS', 'CAPIVARI', 'DOURADOS',
#        'NOVA OLINDA', 'MOGI GUACU', 'VICOSA DO CEARA', 'PIRASSUNUNGA',
#        'ITAPIRA', 'SALTO', 'TIMBAUBA', 'SETE LAGOAS', 'LONDRINA',
#        'PAULINIA', 'MEDINA', 'JARAGUA DO SUL', 'PAICANDU', 'INDAIATUBA',
#        'VARGEM GRANDE DO SUL', 'TEOFILO OTONI',
#        'ESPIRITO SANTO DO PINHAL', 'IRACEMAPOLIS', 'RIBEIRAO PRETO',
#        'CASSILANDIA', 'PINHEIROS', 'ITATIBA', 'ARTUR NOGUEIRA',
#        'CASA BRANCA', 'ARUJA', 'MONTE CARMELO', 'ASSIS', 'COROATA',
#        'CAXAMBU', 'FOZ DO IGUACU', 'NITEROI', 'SERTAOZINHO',
#        'RIO DE JANEIRO', 'SANTO ANDRE', 'JESUITAS', 'UMUARAMA', 'ARARI',
#        'MARINGA', 'CAPIM GROSSO', 'GARCA', 'SALVADOR', 'APARECIDA',
#        'SAO JOSE DOS CAMPOS', 'ITAJUBA', 'VOTUPORANGA', 'ANDRADINA',
#        'GUAXUPE', 'ARACAJU', 'CURITIBA', 'PIRAPEMAS', 'POCOS DE CALDAS',
#        'CONTAGEM', 'ARAXA', 'SAO MIGUEL DO ANTA', 'ROLANDIA', 'ILICINEA',
#        'ITUVERAVA', 'SAO LUIS', 'TAQUARITINGA', 'SAO JOAO DA BOA VISTA',
#        'SAO JOAO DE MERITI', 'NOVA ODESSA', 'PIRACICABA', 'OSASCO',
#        'COLOMBO', 'ITACURUBA', 'ITANHANDU', 'NINHEIRA', 'PIRAPORA',
#        'JALES', 'SANTA GERTRUDES', 'SAO BERNARDO DO CAMPO',
#        'BANDEIRANTES', 'PINHALZINHO', 'SAO LUIZ GONZAGA', 'LEME',
#        'GUARUJA', 'MATARACA', 'BACABAL', 'PARATINGA', 'ARARAQUARA',
#        'CASTANHAL', 'SANTOS', 'MUCURI', 'QUEDAS DO IGUACU', 'SOROCABA',
#        'RIBEIRAO GRANDE', 'IBIMIRIM', 'BRASILIA', 'LIMEIRA', 'MACEIO',
#        'MONTES CLAROS', 'ELDORADO', 'ITABIRA', 'IBIUNA',
#        'FEIRA DE SANTANA', 'CAJATI', 'PERUIBE', 'POA', 'PALMAS',
#        'CARAGUATATUBA', 'TERESOPOLIS', 'CAMPO GRANDE', 'DOMINGOS MOURAO',
#        'ITAJAI', 'FLORESTOPOLIS', 'ITAU DE MINAS', 'APARECIDA DO TABOADO',
#        'BELEM', 'SERRA NEGRA', 'GOVERNADOR MANGABEIRA', 'ITARIRI',
#        'EMBU DAS ARTES', 'GOIANDIRA', 'PRAIA GRANDE',
#        'SAO GONCALO DO AMARANTE', 'LOUVEIRA', 'JAGUARIBE', 'DARIO MEIRA',
#        'ITABI', 'ARARAS', 'ALUMINIO', 'CHARQUEADA', 'CARIACICA',
#        'JOAO MONLEVADE', 'PARAIBANO', 'BRASOPOLIS', 'TAVARES',
#        'PEDERNEIRAS', 'UBERLANDIA', 'MACHADO', 'JOINVILLE',
#        'SAO CRISTOVAO', 'CRUZILIA', 'SAO CARLOS', 'CAXIAS DO SUL',
#        'CATAGUASES', 'VITORIA DA CONQUISTA', 'DORES DE CAMPOS',
#        'GUARATINGUETA', "OLHO D'AGUA DAS CUNHAS", 'JARINU',
#        'CALDAS NOVAS', 'TARAUACA', 'VILA VELHA', 'TAIACU',
#        'CONCEICAO DAS ALAGOAS', 'MONTE ALEGRE DO SUL', 'ELIAS FAUSTO',
#        'SANTA RITA DO SAPUCAI', 'ALFENAS', 'CAMANDUCAIA', 'PATROCINIO',
#        'ESPINOSA', 'JANAUBA', 'TANHACU', 'OURO FINO', 'BODOCO',
#        'NOVA LONDRINA', 'MARILIA', 'SAO CAETANO DO SUL', 'SAO VICENTE',
#        'PINDAMONHANGABA', 'ITAPETININGA', "SANTA BARBARA D'OESTE",
#        'BASTOS', 'BOTUCATU', 'TRES LAGOAS', 'ENGENHEIRO COELHO',
#        'FRANCO DA ROCHA', 'MARAGOGI', 'SEBASTIAO LARANJEIRAS', 'PINHAIS',
#        'CARAPICUIBA', 'JUNDIAI DO SUL', 'PRESIDENTE PRUDENTE',
#        'BALNEARIO CAMBORIU', 'JUCATI', 'ERVALIA', 'VITORIA', 'ALTEROSA',
#        'GUARA', 'RIO DAS OSTRAS', 'JEREMOABO', 'SAO LEOPOLDO', 'GOIAS',
#        'TAUBATE', 'GOVERNADOR VALADARES', 'PORTO VELHO', 'JACAREI',
#        'FLORIDA PAULISTA', 'CAUCAIA', 'BOA ESPERANCA', 'DIADEMA', 'AVARE',
#        'CAPELA', 'JEQUIE', 'TERRA NOVA', 'CUIABA', 'ITAPORANGA',
#        'BOTELHOS', 'ANGATUBA', 'ITARARE', 'RESSAQUINHA', 'ITUPEVA',
#        'CAETITE', 'QUATA', 'VICOSA', 'JOAO PESSOA', 'BOM PRINCIPIO',
#        'CACONDE', 'CERQUILHO', 'BARRA BONITA', 'CACHOEIRO DE ITAPEMIRIM',
#        'LORENA', 'BARIRI', 'SAO JOSE DO RIO PARDO', 'GROSSOS', 'CAREACU',
#        'PEDREIRA', 'BIRITIBA-MIRIM', 'CACAPAVA', 'SANTAREM',
#        'MARANHAOZINHO', 'NOVA FRIBURGO', 'PORTO ALEGRE', 'EUNAPOLIS',
#        'TUPA', 'TRES CORACOES', 'UNIAO', 'IBATIBA', 'ARACOIABA',
#        'JOSE BONIFACIO', 'BALSAMO', 'MIRANDA DO NORTE', 'ALAGOINHAS',
#        'ITAPEVI', 'SAPEZAL', 'POUSO ALEGRE', 'DESCALVADO', 'SURUBIM',
#        'MALHADA', 'GOIANIA', 'ARIQUEMES', 'SAO JOSE DO EGITO', 'CANINDE',
#        'SUZANO', 'AVANHANDAVA', 'CACHOEIRA GRANDE',
#        'SAO GABRIEL DA CACHOEIRA', 'MONGAGUA', 'PARANAIBA', 'RINOPOLIS',
#        'CAPAO BONITO', 'ESPERA FELIZ', 'ITAPEVA', 'TAUA', 'ANAJATUBA',
#        'PRESIDENTE VENCESLAU', 'TIETE', 'CAMBE', 'PARAISOPOLIS',
#        'ILHA SOLTEIRA', 'CRUZEIRO DO SUL', 'SAO PEDRO', 'FRANCA',
#        'HOLAMBRA', 'SAO JOAO DEL REI', 'MATO VERDE', 'VARZEA PAULISTA',
#        'MUZAMBINHO', 'LAGES', 'INVALIDO', 'CAMBORIU', 'ITAGI',
#        'FLORESTA AZUL', 'CASCAVEL', 'CACHOEIRA PAULISTA',
#        'BOM JESUS DA LAPA', 'CIANORTE', 'MINAS NOVAS', 'RONDONOPOLIS',
#        'NOVO TRIUNFO', 'TAQUARITUBA', 'BROTAS', 'FREI PAULO',
#        'CAMPOS DOS GOYTACAZES', 'RAFARD', 'LUZIANIA',
#        'SANTA CRUZ DO RIO PARDO', 'SOCORRO', 'VARGEM GRANDE',
#        'JABOATAO DOS GUARARAPES', 'PERDIZES', 'JUAZEIRO DO NORTE',
#        'AGUAI', 'JULIO MESQUITA', 'ITURAMA', 'MOGI DAS CRUZES', 'AREADO',
#        'ITIRAPINA', 'FRUTAL', 'SERRA DO RAMALHO', 'CABO VERDE',
#        'BEBEDOURO', 'PARAGUACU PAULISTA', 'COQUEIRAL', 'BLUMENAU',
#        'ABADIA DOS DOURADOS', 'SORRISO', 'PALMAS DE MONTE ALTO',
#        'CABREUVA', 'CAMBUI', 'MORTUGABA', 'ITAUNA', 'PIUMHI',
#        'TUPANATINGA', 'ANGRA DOS REIS', 'JUIZ DE FORA',
#        'SAO JOSE DOS PINHAIS', 'SAO GONCALO', 'RIO VERDE', 'GUAREI',
#        'IGUABA GRANDE', 'SANTO ANTONIO DE POSSE', 'IMPERATRIZ', 'COROACI',
#        'BRAGANCA PAULISTA', 'CRISOPOLIS', 'CUMARU', 'AMPARO', 'CHORROCHO',
#        'RUBINEIA', 'PRESIDENTE ALVES', 'RIO VERMELHO', 'JACOBINA',
#        'ATALAIA', 'FORMIGA', 'RIBEIRAO PIRES', 'UNIAO DOS PALMARES',
#        'SAO SIMAO', 'PORTO', 'CORDEIROPOLIS', 'ERECHIM', 'ITABERABA',
#        'ATALEIA', 'SAO PEDRO DA UNIAO', 'MARITUBA', 'SAO TOMAS DE AQUINO',
#        'BARREIRAS', 'PRACINHA', 'SAO DOMINGOS DO PRATA', 'ABAETETUBA',
#        'CERQUEIRA CESAR', 'SAO JOSE DA LAJE', 'BOM JESUS DOS PERDOES',
#        'JABOTICABAL', 'OLIVEIRA DOS BREJINHOS', 'JI-PARANA', 'CACERES',
#        'GUANAMBI', 'MAUA', 'VILHENA', 'ESPERANCA', 'ITAPERUNA',
#        'CAIEIRAS', 'PALHOCA', 'ASSIS CHATEAUBRIAND', 'TIMOTEO',
#        'INCONFIDENTES', 'PONTALINDA', 'IBIA', 'TAMBAU',
#        'SAO SEBASTIAO DO PARAISO', 'CAJAMAR', 'UBERABA',
#        'RIBEIRAO DO LARGO', 'RIO POMBA', 'CARDOSO', 'ARAIOSES',
#        'SANTA TERESINHA', 'ITUMBIARA', 'IGUAPE', 'PALMEIRA DOS INDIOS',
#        'MATOES DO NORTE', 'MACAUBAS', 'RIBEIRAO CLARO', 'WITMARSUM',
#        'RIBEIRAO DO PINHAL', 'FEIRA GRANDE', 'EMILIANOPOLIS',
#        'ANANINDEUA', 'CAMPO DO MEIO', 'GUAIRA', 'CARIRIACU', 'MONTE SIAO',
#        'TOLEDO', 'IPAMERI', 'ARAUCARIA', 'CRAVINHOS', 'CARATINGA',
#        'RAUL SOARES', 'ARACOIABA DA SERRA', 'BARCARENA', 'BARRA DO PIRAI',
#        'SAO ROQUE', 'OSVALDO CRUZ', 'DIVINOPOLIS', 'CAMPESTRE',
#        'RIBEIRAO DAS NEVES', 'GENERAL SAMPAIO', 'PADRE MARCOS', 'PASSIRA',
#        'NOVO HAMBURGO', 'INDEPENDENCIA', 'IBICARAI', 'ITAIBA',
#        'PALESTINA', 'ORLANDIA', 'SERRA', 'DEODAPOLIS', 'SAO JOSE',
#        'MINEIROS', 'LAURO DE FREITAS', 'ITAPECERICA DA SERRA', 'POMPEIA',
#        'VERA CRUZ', 'CESARIO LANGE', 'PIRACAIA', 'ITANHAEM',
#        'CARMO DO RIO CLARO', 'CAXIAS', 'FERNANDOPOLIS', 'CANDEIAS',
#        'MACAE', 'OLINDA', 'SIDROLANDIA', 'SANTANA DE PARNAIBA',
#        'IBITINGA', 'LINS', 'MONTEIROPOLIS', 'CRUZEIRO DO OESTE',
#        'TAPIRATIBA', 'PETROLINA', 'CARLOPOLIS', 'GUARANESIA',
#        'VALENTIM GENTIL', 'JUNQUEIROPOLIS', 'CATANDUVA', 'CASSIA',
#        'ALEGRETE DO PIAUI', 'SANTO ANTONIO DA PATRULHA', 'IPUA',
#        'MONTE SANTO DE MINAS', 'CLARAVAL', 'PASSA QUATRO',
#        'FRANCISCO MORATO', 'JOAO NEIVA', 'GIRAU DO PONCIANO',
#        'SANTA RITA DE CALDAS', 'CICERO DANTAS', 'PAO DE ACUCAR',
#        'SAO JOSE DO RIO CLARO', 'IBOTIRAMA', 'MAIRINQUE', 'ESTIVA GERBI',
#        'MATAO', 'COTIA', 'ITAJUIPE', 'SANTO ANTONIO DO JACINTO',
#        'SAO FRANCISCO DO SUL', 'SAO JOSE DA TAPERA', 'CHUPINGUAIA',
#        'JACINTO', 'JUSSARI', 'CAMPO LIMPO PAULISTA', "DIAS D'AVILA",
#        'CAPITAO ENEAS', 'SANTA LUZIA', 'SAO JOSE DA COROA GRANDE',
#        'JATAIZINHO', 'CARMO DE MINAS', 'PIRAJU', 'PRUDENTOPOLIS',
#        'MATINA', 'SERROLANDIA', 'POCOES', 'TRES RIOS', 'PITANGUEIRAS',
#        'NATAL', 'LARANJAL PAULISTA', 'OURINHOS', 'UBATUBA', 'IACU',
#        'COLINA', 'CONSELHEIRO LAFAIETE', 'CACHOEIRA', 'CAMAMU',
#        'GOVERNADOR NUNES FREIRE', 'ALVORADA DO SUL', 'CACOAL',
#        'CAMPO BELO', 'VITORIA DO MEARIM', 'BOM REPOUSO', 'SALINAS',
#        'BONFIM', 'NOVA MUTUM', 'TOCANTINIA', 'BOM JESUS DO GALHO',
#        'FRANCISCO AYRES', 'NACIP RAYDAN', 'DOM ELISEU', 'PEDRA BRANCA',
#        'CAMPO MOURAO', 'EMBU-GUACU', 'VOLTA REDONDA', 'MIGUEL ALVES',
#        'MORUNGABA', 'BIRIGUI', 'URUPES', 'NOVA CANAA PAULISTA',
#        'MATIAS CARDOSO', 'ITAPECURU MIRIM', 'BONITO DE SANTA FE',
#        'PARAUAPEBAS', 'RIO NOVO DO SUL', 'IACANGA', 'LUCELIA', 'IPATINGA',
#        'IPIRANGA DO PIAUI', 'TERRA BOA', 'ANAPOLIS', 'CAPELINHA',
#        'ARACATUBA', 'MARAVILHA', 'PASSOS', 'NOVA LIMA', 'GURUPI',
#        'SAO MATEUS DO MARANHAO', 'PADRE PARAISO', 'CEDRO', 'MONTEZUMA',
#        'CAMPINA GRANDE', 'CUBATAO', 'ALEGRE', 'ICARAIMA', 'BRUMADO',
#        'GUAJARA-MIRIM', 'LAGUNA', 'BARUERI', 'PORTO FERREIRA', 'ITAPOLIS',
#        'SAO JOAO NEPOMUCENO', 'BELEM DO PIAUI', 'TATUI', 'PINDAI',
#        'CHAPECO', 'IEPE', 'SAO DOMINGOS', 'SALINOPOLIS', 'MORRO AGUDO',
#        'CACHOEIRAS DE MACACU', 'SAO MIGUEL DO OESTE', 'REGENTE FEIJO',
#        'SAO SEBASTIAO', 'PORTO FELIZ', 'MIRASSOL', 'RIO GRANDE DA SERRA',
#        'MUCUGE', 'BARBOSA FERRAZ', 'TAMBORIL', 'ILHEUS',
#        'SANTA FE DO SUL', 'GARANHUNS', 'MUNHOZ', 'PONTO DOS VOLANTES',
#        'RIO NEGRO', 'GUARARAPES', 'LARANJAL DO JARI', 'IRAPURU',
#        'SAO BENEDITO', 'CARIRA', 'CABO FRIO', 'ESPIRITO SANTO DO DOURADO',
#        'PAULO JACINTO', 'RUBELITA', 'TORRINHA', 'PACARAIMA',
#        'CAPELA DO ALTO', 'RIACHO DOS MACHADOS', 'COLORADO DO OESTE',
#        'TAPES', 'AGRICOLANDIA', 'ARARUAMA', 'MIMOSO DO SUL',
#        'FRONTEIRA DOS VALES', 'TEIXEIRA DE FREITAS', 'OLIVEIRA',
#        'LIVRAMENTO DE NOSSA SENHORA', 'TRES MARIAS', 'TAQUARA',
#        'TANGARA DA SERRA', 'MANARI', 'PARAPUA', 'PONTAL', 'MONTE BELO',
#        'ALTAMIRA', 'GUAPE', 'PEIXOTO DE AZEVEDO', 'APIAI',
#        'LENCOIS PAULISTA', 'NOVA AURORA', 'JAPARATUBA', 'INHAPIM',
#        'ALTA FLORESTA', 'NATIVIDADE', 'ITAPEMA', 'CAPOEIRAS',
#        'SAO GOTARDO', 'UCHOA', 'BAMBUI', 'BARBALHA', 'SANTA MARIA',
#        'CODO', 'SANTANA DO ITARARE', 'SAO BERNARDO', 'PARANAGUA',
#        'ARIRANHA', 'CATALAO', 'SAO JOAO DA MATA', 'GRAVATAI',
#        'CONCEICAO DA APARECIDA', 'JURANDA', 'POLONI', 'IPUIUNA',
#        'SANTO ANTONIO DO JARDIM', 'CARNAUBAL', 'ITABUNA', 'ALPINOPOLIS',
#        'GUARAPARI', 'BAGE', 'MARIA DA FE', 'CAMARAGIBE', 'DIVINOLANDIA',
#        'GUIMARAES', 'CALDAS', 'MALTA', 'CASIMIRO DE ABREU', 'PATO BRANCO',
#        'SANTA RITA', 'TRINDADE', 'ITAMBE', 'LINDOIA', 'CONCHAL',
#        'IBIRAPITANGA', 'JEQUITINHONHA', 'CHAVANTES', 'PIEDADE', 'CAJURU',
#        'PASSO FUNDO', 'IACRI', 'BARAO DE GRAJAU', 'NOVO ORIENTE',
#        'BOITUVA', 'MACATUBA', 'BARRINHA', 'REGISTRO', 'IBITIURA DE MINAS',
#        'CARMOPOLIS', 'MILAGRES', 'RIO PARDO DE MINAS', 'MONTE APRAZIVEL',
#        'GARIBALDI', 'CASA NOVA', 'BATATAIS', 'BURITIZEIRO', 'GUARACIABA',
#        'NOVA ANDRADINA', 'UBATA', 'JOAO DOURADO', 'CRAIBAS',
#        'BOM SUCESSO', 'PACAEMBU', 'PELOTAS', 'MINACU', 'BONITO DE MINAS',
#        'DELMIRO GOUVEIA', 'ARAGUARI', 'SENADOR MODESTINO GONCALVES',
#        'JENIPAPO DE MINAS', 'COMERCINHO', 'ITATUBA', 'ITUIUTABA',
#        'VARZEA ALEGRE', 'BOMBINHAS', 'ITAMBARACA', 'TOMAR DO GERU',
#        'ARAME', 'NOVA EUROPA', 'PARAISO DO TOCANTINS', 'TAIOBEIRAS',
#        'NAVEGANTES', 'FEIRA NOVA', 'PONTA GROSSA',
#        'DEPUTADO IRAPUAN PINHEIRO', 'MATA GRANDE', 'CAMPO FORMOSO',
#        'PEREIRAS', 'PASSAGEM FRANCA DO PIAUI', 'CAPINOPOLIS', 'SALMOURAO',
#        'CAJUEIRO', 'ENTRE RIOS DO OESTE', 'JUTAI', 'CORUMBA',
#        'SANTA MARIA DO SALTO', 'MARECHAL CANDIDO RONDON',
#        'SENADOR JOSE PORFIRIO', 'CAMPANHA', 'SANTA MARIA DA VITORIA',
#        'TUCANO', 'CIDADE OCIDENTAL', 'AREAL', 'ESTRELA DE ALAGOAS',
#        'NOVA PONTE', 'AGUAS FORMOSAS', 'BARRETOS', 'VENTUROSA',
#        'AGUAS DE LINDOIA', 'OURO VERDE', 'JANDAIA DO SUL', 'ITAJOBI',
#        'PARAGOMINAS', 'NOVA IGUACU', 'URUBURETAMA', 'RIVERSUL', 'URANIA',
#        'RESENDE', 'SANTANOPOLIS', 'SAO JOAQUIM DA BARRA', 'ALAMBARI',
#        'MAGE', 'ESPIRITO SANTO', 'HUGO NAPOLEAO', 'PARANAVAI', 'TARRAFAS',
#        'ITATIRA', 'BUENO BRANDAO', 'FLORES', 'IBAITI',
#        'SAO SEBASTIAO DA GRAMA', 'CONCHAS', 'RIO BRANCO', 'AGUDOS',
#        'GUARACAI', 'OURICURI', 'RENASCENCA', 'ARAPIRACA', 'MAIRIPORA',
#        'LAJEADO', 'CANTANHEDE', 'TAQUARANA', 'PENAPOLIS',
#        'DUQUE DE CAXIAS', 'UTINGA', 'CURVELO', 'MIGUEL CALMON',
#        'PORTO SEGURO', 'TEOFILANDIA', 'IPERO', 'SAO PEDRO DO TURVO',
#        'BOA NOVA', 'ITAPETINGA', 'MARILUZ', 'JAGUAQUARA', 'SAO MANUEL',
#        'BERTIOGA', 'JATAI', 'IGARACY', 'JATOBA DO PIAUI', 'ARINOS',
#        'CABECEIRAS DO PIAUI', 'JAIBA', 'PATOS DE MINAS', 'MACAPA',
#        'TIMON', 'PARISI', 'PRUDENTE DE MORAIS', 'BETIM', 'MAGDA',
#        'PARANAITA', 'ITAPE', 'PANORAMA', 'TABOAO DA SERRA', 'VOTORANTIM',
#        'TEUTONIA', 'MATINHA', 'PRESIDENTE EPITACIO', 'BOM DESPACHO',
#        'BREJO DE AREIA', 'CURRAL NOVO DO PIAUI', 'PRESIDENTE VARGAS',
#        'ARACUAI', 'LARANJEIRAS DO SUL', 'NOVA IBIA', 'MOREIRA SALES',
#        'SERIDO', 'PENEDO', 'PEDREGULHO', 'INHAMBUPE', 'CAMACARI',
#        'ARARIPE', 'PIRACURUCA', 'LUIS ANTONIO',
#        'SANTA BARBARA DO MONTE VERDE', 'SERINGUEIRAS', 'ANCHIETA',
#        'PAULO AFONSO', 'LIMOEIRO DO NORTE', 'MACAMBIRA'], dtype=object)

# %%
#analisando o endereço dos pacientes
groupEndPaciente = covidCampinas_df.groupby(['paciente_endereco_nmmunicipio']).size().reset_index(name='count_rows')
groupEndPaciente.sort_values('count_rows', ascending=False)
# Out:
#     paciente_endereco_nmmunicipio  count_rows
# 147                      CAMPINAS       23705
# 757                     SAO PAULO         304
# 321                   HORTOLANDIA         303
# 784                        SUMARE         225
# 843                      VALINHOS         183
# ..                            ...         ...
# 359                       IRAPURU           1
# 360                     ITABERABA           1
# 362                       ITABIRA           1
# 363                      ITABORAI           1
# 862                     WITMARSUM           1
#
# [863 rows x 2 columns]

# %%
#analisando o nome fantasia dos estabelecimentos em Campinas
groupEstabNome = covidCampinas_df.groupby(['estalecimento_nofantasia']).size().reset_index(name='count_rows')
groupEstabNome.sort_values('count_rows', ascending=False)
# Out:
#                      estalecimento_nofantasia  count_rows
# 97                  VIGILANCIA EM SAUDE LESTE        1614
# 77                   DISTRITO SANITARIO NORTE        1440
# 78                DISTRITO SANITARIO SUDOESTE        1341
# 99                    VIGILANCIA EM SAUDE SUL        1275
# 98               VIGILANCIA EM SAUDE NOROESTE        1262
# ..                                        ...         ...
# 92  PENITENCIARIA DO SAO BERNARDO DE CAMPINAS           3
# 2                                    CAMPIMED           2
# 87                       HOSPITAL SANTA SOFIA           1
# 11             CENTRO DE SAUDE CAMPINA GRANDE           1
# 96                          SOBRAPAR CAMPINAS           1
#
# [100 rows x 2 columns]

# %%
#valores únicos dos grupos de atendimento
covidCampinas_df['vacina_grupoatendimento_nome'].unique()
# Out:
# array(['Pessoas de 18 a 64 anos',
#        'Doenças Cardiovasculares e Cerebrovasculares',
#        'Pessoas de 70 a 74 anos', 'Pessoas de 75 a 79 anos',
#        'Pessoas de 80 anos ou mais', 'Pessoas de 65 a 69 anos', 'Outros',
#        'Hipertensão de difícil controle ou com complicações/lesão de órgão alvo',
#        'Gestante', 'Diabetes Mellitus', 'Ensino Básico',
#        'Outros Imunocomprometidos', 'Segurança',
#        'Pessoas com Deficiência Permanente', 'Obesidade Grave (Imc≥40)',
#        'Neoplasias', 'Pessoas de 60 nos ou mais Institucionalizadas',
#        'Aéreo', 'Coletivo Rodoviário Passageiros Urbano e de Longo Curso',
#        'Pneumopatias Crônicas Graves', 'Doença neurológica crônica',
#        'Doença Renal Crônica',
#        'Pessoas com Deficiência Institucionalizadas', 'Puérpera',
#        'Indivíduos Transplantados de Órgão Sólido', 'Síndrome de Down',
#        'Povos indígenas em terras indígenas',
#        'Pessoas em Situação de Rua', 'Quilombola'], dtype=object)

# %%
#valores únicos dos fabricantes das vacinas 
covidCampinas_df['vacina_fabricante_nome'].unique()
# Out:
# array(['PFIZER', 'ASTRAZENECA/FIOCRUZ', 'SINOVAC/BUTANTAN', 'JANSSEN'],
#       dtype=object)

# %%
#agrupando pelos fabricantes das vacinas 
groupVacTipo = covidCampinas_df.groupby(['vacina_descricao_dose', 'vacina_fabricante_nome']).size().reset_index(name='count_rows')
groupVacTipo
# Out:
#   vacina_descricao_dose vacina_fabricante_nome  count_rows
# 0               1ª Dose    ASTRAZENECA/FIOCRUZ        4353
# 1               1ª Dose                 PFIZER        2714
# 2               1ª Dose       SINOVAC/BUTANTAN        3701
# 3               2ª Dose    ASTRAZENECA/FIOCRUZ        6342
# 4               2ª Dose                 PFIZER        2707
# 5               2ª Dose       SINOVAC/BUTANTAN        5344
# 6                  Dose                JANSSEN        1055
# 7               Reforço    ASTRAZENECA/FIOCRUZ           2
# 8               Reforço                 PFIZER        1034
# 9               Reforço       SINOVAC/BUTANTAN         314

# %%
groupVacTipo2 = groupVacTipo.drop([6])
groupVacTipo2
# Out:
#   vacina_descricao_dose vacina_fabricante_nome  count_rows
# 0               1ª Dose    ASTRAZENECA/FIOCRUZ        4353
# 1               1ª Dose                 PFIZER        2714
# 2               1ª Dose       SINOVAC/BUTANTAN        3701
# 3               2ª Dose    ASTRAZENECA/FIOCRUZ        6342
# 4               2ª Dose                 PFIZER        2707
# 5               2ª Dose       SINOVAC/BUTANTAN        5344
# 7               Reforço    ASTRAZENECA/FIOCRUZ           2
# 8               Reforço                 PFIZER        1034
# 9               Reforço       SINOVAC/BUTANTAN         314

# %%
#comparando as doses com os fabricantes das vacinas
groupVacTipo2.pivot("vacina_descricao_dose", "vacina_fabricante_nome", "count_rows").plot(kind='bar', figsize=(10, 8), rot=0)

plt.show()

# %%
#agrupando pelos fabricantes das vacinas - 2 
groupVacTipo2 = covidCampinas_df.groupby(['vacina_fabricante_nome']).size().reset_index(name='count_rows')
groupVacTipo2
# Out:
#   vacina_fabricante_nome  count_rows
# 0    ASTRAZENECA/FIOCRUZ       10697
# 1                JANSSEN        1055
# 2                 PFIZER        6455
# 3       SINOVAC/BUTANTAN        9359

# %%
#plotando o fabricante da vacina vs quantidade utilizada
ax = groupVacTipo2.plot.bar(figsize=(10, 8), rot=0);

# %%
#mudando o index do gráfico
groupVacTipo2.set_index('vacina_fabricante_nome').plot(kind='bar', figsize=(10, 8), rot=0);

# %%
#agrupando pelos grupos de atendimento
groupVacTipo = covidCampinas_df.groupby(['vacina_grupoatendimento_nome']).size().reset_index(name='count_rows')
groupVacTipo
# Out:
#                          vacina_grupoatendimento_nome  count_rows
# 0                                               Aéreo         219
# 1   Coletivo Rodoviário Passageiros Urbano e de Lo...          69
# 2                                   Diabetes Mellitus         714
# 3                                Doença Renal Crônica          30
# 4                          Doença neurológica crônica          38
# 5        Doenças Cardiovasculares e Cerebrovasculares         204
# 6                                       Ensino Básico         570
# 7                                            Gestante          79
# 8   Hipertensão de difícil controle ou com complic...        1248
# 9           Indivíduos Transplantados de Órgão Sólido          21
# 10                                         Neoplasias         100
# 11                           Obesidade Grave (Imc≥40)         190
# 12                                             Outros        3037
# 13                          Outros Imunocomprometidos         437
# 14        Pessoas com Deficiência Institucionalizadas           6
# 15                 Pessoas com Deficiência Permanente         151
# 16                            Pessoas de 18 a 64 anos       15422
# 17      Pessoas de 60 nos ou mais Institucionalizadas         108
# 18                            Pessoas de 65 a 69 anos        1334
# 19                            Pessoas de 70 a 74 anos        1348
# 20                            Pessoas de 75 a 79 anos         877
# 21                         Pessoas de 80 anos ou mais        1028
# 22                         Pessoas em Situação de Rua          34
# 23                       Pneumopatias Crônicas Graves         236
# 24                Povos indígenas em terras indígenas           3
# 25                                           Puérpera          15
# 26                                         Quilombola           1
# 27                                          Segurança          31
# 28                                   Síndrome de Down          16

# %%
#mudando o index do gráfico
groupVacTipo.set_index('vacina_grupoatendimento_nome').plot(kind='bar', figsize=(25, 10), rot=90);

# %%
#Entendendo melhor o grupo de pessoas que receberam a dose de reforço
doseReforco = covidCampinas_df.query('vacina_descricao_dose=="Reforço"')
doseReforco['vacina_descricao_dose'].unique()
# Out:
# array(['Reforço'], dtype=object)

# %%
doseReforco.head(5)
# Out:
#                                              paciente_id  ...  vacina_numdose
# 10256  47e44da5406084f49195c8841586f7eee3b2814ae61a55...  ...              38
# 10257  5fd5772c93101e671d9f7bb5ba6186b642f7803a85d5f2...  ...              38
# 10258  eb886cc79f269e2a964a5507bc179d03b07d984aeebd12...  ...              38
# 10259  6066f29e1f89a6b86ae27ad6bfc90d0ab8f71127591875...  ...              38
# 10262  9781c6198e88503aabdd5f8451fa8df78daf26ec39a143...  ...              38
#
# [5 rows x 32 columns]

# %%
doseReforco.shape
# Out:
# (1350, 32)

# %%
#verificando os grupos que receberam a dose de reforço
doseReforco['vacina_grupoatendimento_nome'].unique()
# Out:
# array(['Outros', 'Pessoas de 70 a 74 anos', 'Pessoas de 80 anos ou mais',
#        'Pessoas de 75 a 79 anos', 'Pessoas de 65 a 69 anos',
#        'Pessoas de 60 nos ou mais Institucionalizadas',
#        'Pessoas de 18 a 64 anos', 'Ensino Básico',
#        'Outros Imunocomprometidos'], dtype=object)

# %%
#varificando o nome das categorias da vacina para o grupo que recebeu a dose de reforço
doseReforco['vacina_categoria_nome'].unique()
# Out:
# array(['Trabalhadores de Saúde', 'Faixa Etária',
#        'Pessoas de 60 anos ou mais institucionalizadas',
#        'Trabalhadores da Educação', 'Comorbidades'], dtype=object)

# %%
#Agrupando o dataframe com apenas dados da dose de reforço
group_doseReforco_grupo = doseReforco.groupby(['vacina_grupoatendimento_nome']).size().reset_index(name="count_rows")
group_doseReforco_grupo
# Out:
#                     vacina_grupoatendimento_nome  count_rows
# 0                                  Ensino Básico           2
# 1                                         Outros         507
# 2                      Outros Imunocomprometidos           3
# 3                        Pessoas de 18 a 64 anos          13
# 4  Pessoas de 60 nos ou mais Institucionalizadas          21
# 5                        Pessoas de 65 a 69 anos          74
# 6                        Pessoas de 70 a 74 anos         349
# 7                        Pessoas de 75 a 79 anos         222
# 8                     Pessoas de 80 anos ou mais         159

# %%
#plotando o grupo que recebeu a dose reforço
group_doseReforco_grupo.set_index('vacina_grupoatendimento_nome').plot(kind='bar', figsize=(24,10), rot=45);

# %%
#Agrupando o dataframe com apenas dados da dose de reforço
group_doseReforco_sexo = doseReforco.groupby(['paciente_enumsexobiologico']).size().reset_index(name="count_rows")
group_doseReforco_sexo
# Out:
#   paciente_enumsexobiologico  count_rows
# 0                          F         873
# 1                          M         477

# %%
#plotando o sexo que recebeu a dose reforço
group_doseReforco_sexo.set_index('paciente_enumsexobiologico').plot(kind='bar', figsize=(10,8), rot=0);

#muitas mais mulheres receberam a dose reforço do que os homens

# %%
#Agrupando o dataframe com apenas dados da dose de reforço
group_doseReforco_categ = doseReforco.groupby(['vacina_categoria_nome']).size().reset_index(name="count_rows")
group_doseReforco_categ
# Out:
#                             vacina_categoria_nome  count_rows
# 0                                    Comorbidades           3
# 1                                    Faixa Etária         817
# 2  Pessoas de 60 anos ou mais institucionalizadas          21
# 3                       Trabalhadores da Educação           2
# 4                          Trabalhadores de Saúde         507

# %%
#plotando a categoria das pessoas que receberam a dose reforço
group_doseReforco_categ.set_index('vacina_categoria_nome').plot(kind='bar', figsize=(10,8), rot=45);

# %%
#entendendo os grupos que são representados pelo nome da categoria igual a "Faixa Etária"
categFaixaEtaria = doseReforco.query('vacina_categoria_nome == "Faixa Etária"')
categFaixaEtaria['vacina_grupoatendimento_nome'].unique()

#não tem uma faixa etária específica.
# Out:
# array(['Pessoas de 70 a 74 anos', 'Pessoas de 80 anos ou mais',
#        'Pessoas de 75 a 79 anos', 'Pessoas de 65 a 69 anos',
#        'Pessoas de 18 a 64 anos'], dtype=object)

# %%
#Para categoria igual a "Faixa Etária", contabilizando os grupos de atendimento
categFaixaEtaria2 = categFaixaEtaria.groupby(['vacina_grupoatendimento_nome']).size().reset_index(name="count_rows")
categFaixaEtaria2
# Out:
#   vacina_grupoatendimento_nome  count_rows
# 0      Pessoas de 18 a 64 anos          13
# 1      Pessoas de 65 a 69 anos          74
# 2      Pessoas de 70 a 74 anos         349
# 3      Pessoas de 75 a 79 anos         222
# 4   Pessoas de 80 anos ou mais         159

# %%
#plotando a categoria das pessoas que receberam a dose reforço
categFaixaEtaria2.set_index('vacina_grupoatendimento_nome').plot(kind='bar', figsize=(10,8), rot=45);

#a dose reforço foi majoritariamente aplicada e pessoas com faixa etária entre 70 e 74 anos

# %%
#verificando se há id's dos pacientes repetidos no dataset original
diff = len(covidCampinas_df['paciente_id']) - len(covidCampinas_df['paciente_id'].unique())
diff
# Out:
# 237

# %%
#decobrindo os id's duplicados

duplicatedIDS = covidCampinas_df[covidCampinas_df.duplicated(subset=['paciente_id'],keep=False)]
duplicatedIDS.head(5)
# Out:
#                                            paciente_id  ...  vacina_numdose
# 11   6d8010384d5f0e447517380dd412ef9c56c0b1aa015ae9...  ...               1
# 36   86a56d9602f410eb6be7a6948ccca2e037cddd09bffa29...  ...               1
# 61   481c9a182fb10e22b23ac83e19ec2f9d49dcd3d1b41a23...  ...               1
# 86   02e316510b503468234e5700259bc50af623ca2428cc83...  ...               1
# 156  57c2563107ba873d466f73f291088329f8cf9787702102...  ...               1
#
# [5 rows x 32 columns]

# %%
#agrupando por ID'S
groupIDS = duplicatedIDS.groupby(['paciente_id','vacina_descricao_dose']).size().reset_index(name="count_rows")
groupIDS
# Out:
#                                            paciente_id  ... count_rows
# 0    00840ac8c758323b8b094aaf1d0b49319c9e5384e04706...  ...          1
# 1    00840ac8c758323b8b094aaf1d0b49319c9e5384e04706...  ...          1
# 2    024a13914f12ec1caf9e4ac40c6b9b5e86e9655dee4739...  ...          1
# 3    024a13914f12ec1caf9e4ac40c6b9b5e86e9655dee4739...  ...          1
# 4    02e316510b503468234e5700259bc50af623ca2428cc83...  ...          1
# ..                                                 ...  ...        ...
# 469  f852836b47b08d641a24d821a14a321208a32c19d980c1...  ...          1
# 470  fa6cd72ae600456c525757ab0cb97c8aedf54de5c1b709...  ...          1
# 471  fa6cd72ae600456c525757ab0cb97c8aedf54de5c1b709...  ...          1
# 472  fcce1e362b0782b48c6bc1251fc8fd5478c671a69f0c3d...  ...          1
# 473  fcce1e362b0782b48c6bc1251fc8fd5478c671a69f0c3d...  ...          1
#
# [474 rows x 3 columns]

# %%
#agrupando por ID'S - 2
groupIDS2 = duplicatedIDS.groupby(['paciente_id'])['vacina_descricao_dose'].size().reset_index(name="count_rows")
groupIDS2
# Out:
#                                            paciente_id  count_rows
# 0    00840ac8c758323b8b094aaf1d0b49319c9e5384e04706...           2
# 1    024a13914f12ec1caf9e4ac40c6b9b5e86e9655dee4739...           2
# 2    02e316510b503468234e5700259bc50af623ca2428cc83...           2
# 3    03a2c45d9c15e0435f7a8e4ddf869a6654136e858bb293...           2
# 4    05535198098c63d8ff303dc85e8be9f05a01150f260ab5...           2
# ..                                                 ...         ...
# 232  f21022b49251ab70f415baf19761154756a65573ae2862...           2
# 233  f3a8033d2d8b6583f90b077ee7d19b0b91a782bf349f98...           2
# 234  f852836b47b08d641a24d821a14a321208a32c19d980c1...           2
# 235  fa6cd72ae600456c525757ab0cb97c8aedf54de5c1b709...           2
# 236  fcce1e362b0782b48c6bc1251fc8fd5478c671a69f0c3d...           2
#
# [237 rows x 2 columns]

# %%
#contando a quantidade de doses que foram fornecidas ao total
groupDoseID = duplicatedIDS.groupby(['vacina_descricao_dose']).size().reset_index(name="count_rows")
groupDoseID
# Out:
#   vacina_descricao_dose  count_rows
# 0               1ª Dose         214
# 1               2ª Dose         215
# 2               Reforço          45

# %%
def doses(id):
  result = []
  rows = duplicatedIDS.query('paciente_id == @id')
  doses = list(rows['vacina_descricao_dose'])
  vacinas = list(rows['vacina_fabricante_nome'])

  doses.sort()
  vacinas.sort()

  dosesString = '_'.join(dose for dose in doses)
  vacinasString = '_'.join(vacina for vacina in vacinas)

  result.append(id)
  result.append(dosesString)
  result.append(vacinasString)
  return result


final = []  
for i in range(len(groupIDS2)):
  result = doses(groupIDS2['paciente_id'].iloc[i])
  final.append(result)

final_df = pd.DataFrame(final, columns=['id', 'doses', 'vacinas'])
final_df
# Out:
#                                                     id  ...                                  vacinas
# 0    00840ac8c758323b8b094aaf1d0b49319c9e5384e04706...  ...        SINOVAC/BUTANTAN_SINOVAC/BUTANTAN
# 1    024a13914f12ec1caf9e4ac40c6b9b5e86e9655dee4739...  ...  ASTRAZENECA/FIOCRUZ_ASTRAZENECA/FIOCRUZ
# 2    02e316510b503468234e5700259bc50af623ca2428cc83...  ...  ASTRAZENECA/FIOCRUZ_ASTRAZENECA/FIOCRUZ
# 3    03a2c45d9c15e0435f7a8e4ddf869a6654136e858bb293...  ...  ASTRAZENECA/FIOCRUZ_ASTRAZENECA/FIOCRUZ
# 4    05535198098c63d8ff303dc85e8be9f05a01150f260ab5...  ...        SINOVAC/BUTANTAN_SINOVAC/BUTANTAN
# ..                                                 ...  ...                                      ...
# 232  f21022b49251ab70f415baf19761154756a65573ae2862...  ...        SINOVAC/BUTANTAN_SINOVAC/BUTANTAN
# 233  f3a8033d2d8b6583f90b077ee7d19b0b91a782bf349f98...  ...        SINOVAC/BUTANTAN_SINOVAC/BUTANTAN
# 234  f852836b47b08d641a24d821a14a321208a32c19d980c1...  ...                            PFIZER_PFIZER
# 235  fa6cd72ae600456c525757ab0cb97c8aedf54de5c1b709...  ...  ASTRAZENECA/FIOCRUZ_ASTRAZENECA/FIOCRUZ
# 236  fcce1e362b0782b48c6bc1251fc8fd5478c671a69f0c3d...  ...        SINOVAC/BUTANTAN_SINOVAC/BUTANTAN
#
# [237 rows x 3 columns]

# %%
#agrupando pelas doses
groupFinalDoses = final_df.groupby(['doses']).size().reset_index(name='count')

groupFinalDoses
# Out:
#              doses  count
# 0  1ª Dose_2ª Dose    192
# 1  1ª Dose_Reforço     22
# 2  2ª Dose_Reforço     23

# %%
groupFinalDoses.set_index('doses').plot(kind='bar', figsize=(10,8), rot=45);

# %%
#agrupando pelas doses e vacinas
groupFinalDosesVacinas = final_df.groupby(['doses', 'vacinas']).size().reset_index(name='count')

groupFinalDosesVacinas
# Out:
#              doses                                  vacinas  count
# 0  1ª Dose_2ª Dose  ASTRAZENECA/FIOCRUZ_ASTRAZENECA/FIOCRUZ     87
# 1  1ª Dose_2ª Dose               ASTRAZENECA/FIOCRUZ_PFIZER      2
# 2  1ª Dose_2ª Dose                            PFIZER_PFIZER     26
# 3  1ª Dose_2ª Dose        SINOVAC/BUTANTAN_SINOVAC/BUTANTAN     77
# 4  1ª Dose_Reforço               ASTRAZENECA/FIOCRUZ_PFIZER      1
# 5  1ª Dose_Reforço                  PFIZER_SINOVAC/BUTANTAN     17
# 6  1ª Dose_Reforço        SINOVAC/BUTANTAN_SINOVAC/BUTANTAN      4
# 7  2ª Dose_Reforço               ASTRAZENECA/FIOCRUZ_PFIZER      2
# 8  2ª Dose_Reforço                  PFIZER_SINOVAC/BUTANTAN     15
# 9  2ª Dose_Reforço        SINOVAC/BUTANTAN_SINOVAC/BUTANTAN      6

# %%
#plotando o gráfico da tabela pivot
groupFinalDosesVacinas.pivot("doses", "vacinas", "count").plot(kind='bar', figsize = (20,10), rot= 0)

plt.show()
